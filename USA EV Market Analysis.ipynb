# %% [markdown]
# <div style="background: linear-gradient(to right, yellow, lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>EV Market Analysis-USA</strong>
#   </p>
# </div>

# %%
import pandas as pd 
ev_df= pd.read_csv(r"C:\Users\priyanka\Favorites\Downloads\EV_Data.csv")
ev_df
# Out:
#      Unnamed: 0.1  Unnamed: 0          state  year  EV Registrations  \
# 0               0           0        Alabama  2023             13000
# 1               1           1         Alaska  2023              2700
# 2               2           2        Arizona  2023             89800
# 3               3           3       Arkansas  2023              7100
# 4               4           4     California  2023           1256600
# ..            ...         ...            ...   ...               ...
# 403           403         403       Virginia  2016              3100
# 404           404         404     Washington  2016             14900
# 405           405         405  West Virginia  2016               100
# 406           406         406      Wisconsin  2016              2600
# 407           407         407        Wyoming  2016               100
#
#      Total Vehicles  EV Share (%)  Stations  Total Charging Outlets  Level 1  \
# ...

# %%
ev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 36 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0.1                           408 non-null    int64
#  1   Unnamed: 0                             408 non-null    int64
#  2   state                                  408 non-null    object
#  3   year                                   408 non-null    int64
#  4   EV Registrations                       408 non-null    int64
#  5   Total Vehicles                         408 non-null    int64
#  6   EV Share (%)                           408 non-null    float64
#  7   Stations                               408 non-null    int64
#  8   Total Charging Outlets                 408 non-null    int64
#  9   Level 1                                408 non-null    int64
#  10  Level 2                                408 non-null    int64
# ...

# %%
# column by column  count of null value 
ev_df.isnull().sum()
# Out:
# Unnamed: 0.1                               0
# Unnamed: 0                                 0
# state                                      0
# year                                       0
# EV Registrations                           0
# Total Vehicles                             0
# EV Share (%)                               0
# Stations                                   0
# Total Charging Outlets                     0
# Level 1                                    0
# Level 2                                    0
# DC Fast                                    0
# fuel_economy                             102
# Incentives                                 8
# Number of Metro Organizing Committees     51
# Population_20_64                           0
# Education_Bachelor                         0
# Labour_Force_Participation_Rate            0
# Unemployment_Rate                          0
# Bachelor_Attainment                        0
# Per_Cap_Income                             0
# ...

# %%
# sum of null values in whole data set 
ev_df.isnull().sum().sum()
# Out:
# 1613

# %%
# replace NaN value with "null" 
ev_df=ev_df.fillna(0)

# %%
# sum of total registration
total_registration=ev_df['EV Registrations'].sum()
total_registration
# Out:
# 10485100

# %%
ev_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'state', 'year', 'EV Registrations',
#        'Total Vehicles', 'EV Share (%)', 'Stations', 'Total Charging Outlets',
#        'Level 1', 'Level 2', 'DC Fast', 'fuel_economy', 'Incentives',
#        'Number of Metro Organizing Committees', 'Population_20_64',
#        'Education_Bachelor', 'Labour_Force_Participation_Rate',
#        'Unemployment_Rate', 'Bachelor_Attainment', 'Per_Cap_Income',
#        'affectweather', 'devharm', 'discuss', 'exp', 'localofficials',
#        'personal', 'reducetax', 'regulate', 'worried', 'price_cents_per_kwh',
#        'gasoline_price_per_gallon', 'Total', 'Trucks', 'Trucks_Share',
#        'Party'],
#       dtype='object')

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow, lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>How has EV adoption changed in the USA over time</strong>
#   </p>
# </div>

# %%
import matplotlib.pyplot as plt

# Group by year and sum EV Registrations  How has EV adoption changed in the USA over tim
ev_yearly = ev_df.groupby("year")["EV Registrations"].sum().reset_index()
plt.figure(figsize=(10, 5))
plt.plot(ev_yearly["year"], ev_yearly["EV Registrations"], marker='o', color='chartreuse')
for x, y in zip(ev_yearly["year"], ev_yearly["EV Registrations"]):
    label = f"{round(y / 1_000_000, 1)}M" 
    plt.text(x, y, label, fontsize=9, ha='center', va='bottom',color='green')
plt.title("Total EV Registrations in the USA (Year-wise)")
plt.xlabel("Year")
plt.ylabel("EV Registrations")
plt.tight_layout()
plt.show()

# from 2021, the EV market experienced a boom in registration, and the year  2023, the came with a drastic high registration than 2026 to 2020.

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow, lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Is There a Relationship Between Income Levels and EV Share?</strong>
#   </p>
# </div>

# %%
import seaborn as sns                                             
ev_income = ev_df[['Per_Cap_Income', 'EV Share (%)']].dropna()

plt.figure(figsize=(10,5))
sns.regplot(x='Per_Cap_Income',y='EV Share (%)',data=ev_income, scatter_kws={"alpha": 0.4})
plt.title("Relationship between income level and EV share(%)")
plt.xlabel("per capita income (USD)")
plt.ylabel("EV Share (%)")
plt.show()

correlation = ev_income["Per_Cap_Income"].corr(ev_income["EV Share (%)"])
print(f"Correlation between Income and EV Share: {correlation:.2f}")

# A range of income levels from 20000 to 40000 do not prefer the EV; rather, you can say they cannot afford an EV.
# but above the 50000 income level, people are buying the EV, and it is also affordable for that category of people.
# Out:
# Correlation between Income and EV Share: 0.67

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Which states have the most public charging stations per EV?</strong>
#   </p>
# </div>

# %%
plt.figure(figsize=(10,7))                     
ev_station=ev_df.groupby("state")['Total Charging Outlets'].sum()
ev_station = ev_station.sort_values(ascending=False).head(5)

bars=plt.bar(ev_station.index, ev_station.values,color="chartreuse")
plt.xlabel("Total Charging Outlets")
plt.ylabel("State")
plt.title("Total Charging Outlets by State")
plt.tight_layout()
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height() + 5,
             str(int(bar.get_height())),
             ha='center', va='bottom',color="green")

plt.show()

# California is on top of the chart in charging outlets 
# "One reason California ranks highest in charging outlets is that many multimillionaires, actors, and actresses live there. 
# Since electric vehicles (EVs) are relatively expensive, regions with higher income levels tend to see greater EV adoption
# and supporting infrastructure."

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Is electricity price impacting EV adoption?</strong>
#   </p>
# </div>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=ev_df, x='price_cents_per_kwh', y='EV Registrations',color="chartreuse")   
plt.title("Electricity price impacting EV adoption")
plt.xlabel("Electricity price cents per KWH")
plt.ylabel("EV Registration")

# This suggests that lower electricity prices are associated with higher EV adoption.
# It means if a company wants to increase their EV profit, then they need to manufacture cars or any EV components that take low power to be charged.
# Out:
# Text(0, 0.5, 'EV Registration')

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Is there a relationship between political affiliation and electric vehicle adoption?</strong>
#   </p>
# </div>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=ev_df,x='Number of Metro Organizing Committees',y='EV Registrations',color="chartreuse")
plt.title("relationship between political affiliation and electric vehicle adoption")
plt.xlabel("number of political committees")
correlation=ev_df['Number of Metro Organizing Committees'].corr(ev_df['EV Registrations'])
print("correlation:",correlation)

#This visualization might suggest that areas with more active political committees tend to have higher EV adoption.
# Out:
# correlation: 0.302687918015925

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Which U.S. states have the highest EV adoption (%)?</strong>
#   </p>
# </div>

# %%
ev_share=ev_df.dropna(subset=(['state','EV Share (%)']))            
ev_state_share=ev_share.groupby('state')['EV Share (%)'].mean()
top_state=ev_state_share.sort_values(ascending=True).head(10)
plt.figure(figsize=(10,5))
plt.barh(top_state.index,top_state.values,color="chartreuse")
plt.title("top 10 US States EV adoption")
plt.xlabel("EV shares (%)")
plt.show()

# there is new state are adopting the EV . there is no shock if a one of the state in top 10 are left behind one of the leading Ev adopted State like 
# california

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>What’s the correlation between education level and EV ownership?</strong>
#   </p>
# </div>

# %%
ev_corr=ev_df[['Education_Bachelor','EV Share (%)']].dropna()
correlation1=ev_corr['Education_Bachelor'].corr(ev_df['EV Share (%)'])
print("correlation:",correlation1)
plt.figure(figsize=(10,5))
plt.scatter(ev_corr['Education_Bachelor'],ev_corr['EV Share (%)'],color="lightskyblue")
plt.xlabel("Education (% with Bachelor's Degree)")
plt.ylabel("EV Share (%)")
plt.grid(True)
plt.show()

#This graph suggests that education level might influence EV adoption, possibly due to greater environmental awareness, income levels, or access
#to new technologies among more educated populations. But other factors like infrastructure, policy, and income likely play a role too.
# Out:
# correlation: 0.3404078033688141

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Top 5 states with the best EV infrastructure per capita</strong>
#   </p>
# </div>

# %%
state=ev_df.dropna(subset=(['state','Per_Cap_Income']))
top_state=state.groupby("state")["Per_Cap_Income"].sum()
top5_state=top_state.sort_values(ascending=True).head(5)
plt.figure(figsize=(15,5))
plt.barh(top5_state.index,top5_state.values,color="chartreuse")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow,lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Does unemployment rate affect EV registration?</strong>
#   </p>
# </div>

# %%
ev_affect=ev_df[['Unemployment_Rate', 'EV Registrations']].dropna()
corr=ev_df['Unemployment_Rate'].corr(ev_df['EV Registrations'])
print("correlation:-",corr)
plt.figure(figsize=(11,5))
sns.regplot(x='Unemployment_Rate',y='EV Registrations',data=ev_affect , color="goldenrod")
plt.title("affectation of umemployment on EV registration")
plt.grid(True)
plt.show()
# Out:
# correlation:- 0.09702058463519622

# %% [markdown]
# <div style="background: linear-gradient(to right, yellow, lime); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000;">
#     <strong>Which state had the highest YoY growth in EV registrations?</strong>
#   </p>
# </div>

# %%
top_state = ev_df.groupby(['year','state'])['EV Registrations'].sum().reset_index()
yoy_state = top_state.sort_values(by=['state','year'])
yoy_state = yoy_state[yoy_state['EV Registrations'] != 0]
yoy_state['YOY growth (%)'] = yoy_state.groupby('state')['EV Registrations'].pct_change() * 100
state_1 = yoy_state.dropna(subset=['YOY growth (%)'])
yoy = state_1.loc[state_1['YOY growth (%)'].idxmax()]
print("State with Highest YoY Growth in EV Registrations:")
print(yoy)
# Oklahoma experienced the highest year-over-year growth in EV registrations, with an increase of 208.33% in 2018.
# Out:
# State with Highest YoY Growth in EV Registrations:
# year                      2018
# state                 Oklahoma
# EV Registrations          3700
# YOY growth (%)      208.333333
# Name: 138, dtype: object
